# %%
# !pip install bs4

# %% [markdown]
# https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20200201

# %%
import pandas as pd

# %%
mov_data = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date='

# %%
data = pd.read_html(mov_data)
data
# Out:
# [    순위              영화명  평점  평점.1  평점.2  변동폭  변동폭.1  Unnamed: 7
#  0  NaN              NaN NaN   NaN   NaN  NaN    NaN         NaN
#  1  NaN             가버나움 NaN  9.59  평점주기  NaN    0.0         NaN
#  2  NaN           위대한 쇼맨 NaN  9.40  평점주기  NaN    0.0         NaN
#  3  NaN              알라딘 NaN  9.38  평점주기  NaN    0.0         NaN
#  4  NaN           다크 나이트 NaN  9.34  평점주기  NaN    1.0         NaN
#  5  NaN          소년시절의 너 NaN  9.33  평점주기  NaN    1.0         NaN
#  6  NaN           시네마 천국 NaN  9.31  평점주기  NaN    1.0         NaN
#  7  NaN      패왕별희 디 오리지널 NaN  9.31  평점주기  NaN    1.0         NaN
#  8  NaN        피아니스트의 전설 NaN  9.25  평점주기  NaN    2.0         NaN
#  9  NaN              우리들 NaN  9.25  평점주기  NaN    0.0         NaN
#  10 NaN              톰보이 NaN  9.23  평점주기  NaN    1.0         NaN
#  11 NaN              NaN NaN   NaN   NaN  NaN    NaN         NaN
#  12 NaN          스타 이즈 본 NaN  9.18  평점주기  NaN    1.0         NaN
# ...

# %%
type(data), len(data)
# Out:
# (list, 2)

# %%
df = data[0]

# %%
df.head()
# Out:
#    순위     영화명  평점  평점.1  평점.2  변동폭  변동폭.1  Unnamed: 7
# 0 NaN     NaN NaN   NaN   NaN  NaN    NaN         NaN
# 1 NaN    가버나움 NaN  9.59  평점주기  NaN    0.0         NaN
# 2 NaN  위대한 쇼맨 NaN  9.40  평점주기  NaN    0.0         NaN
# 3 NaN     알라딘 NaN  9.38  평점주기  NaN    0.0         NaN
# 4 NaN  다크 나이트 NaN  9.34  평점주기  NaN    1.0         NaN

# %%
data[1]
# Out:
#     0   1      2        3        4     5              6
# 0  구분   N  Range  Minimum  Maximum  Mean  Std.Deviation
# 1  평점  26   4.39     4.75     9.14  7.59           7.59

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
# 순위            0 non-null float64
# 영화명           50 non-null object
# 평점            0 non-null float64
# 평점.1          50 non-null float64
# 평점.2          50 non-null object
# 변동폭           0 non-null float64
# 변동폭.1         49 non-null float64
# Unnamed: 7    0 non-null float64
# dtypes: float64(6), object(2)
# memory usage: 3.6+ KB

# %%
df['영화명'].head()
# Out:
# 0       NaN
# 1      가버나움
# 2    위대한 쇼맨
# 3       알라딘
# 4    다크 나이트
# Name: 영화명, dtype: object

# %%
pick = ['순위', '영화명', '평점.1']
df2 = df[pick]

# %%
df2
# Out:
#     순위              영화명  평점.1
# 0  NaN              NaN   NaN
# 1  NaN             가버나움  9.59
# 2  NaN           위대한 쇼맨  9.40
# 3  NaN              알라딘  9.38
# 4  NaN           다크 나이트  9.34
# 5  NaN          소년시절의 너  9.33
# 6  NaN           시네마 천국  9.31
# 7  NaN      패왕별희 디 오리지널  9.31
# 8  NaN        피아니스트의 전설  9.25
# 9  NaN              우리들  9.25
# 10 NaN              톰보이  9.23
# 11 NaN              NaN   NaN
# 12 NaN          스타 이즈 본  9.18
# 13 NaN              싸이코  9.11
# 14 NaN      타오르는 여인의 초상  9.05
# 15 NaN          미스비헤이비어  9.04
# 16 NaN           인생 후르츠  9.02
# 17 NaN              미져리  9.02
# 18 NaN     안녕, 나의 소울메이트  8.98
# 19 NaN    온워드: 단 하루의 기적  8.96
# 20 NaN               미션  8.92
# 21 NaN     바르다가 사랑한 얼굴들  8.89
# 22 NaN              NaN   NaN
# 23 NaN        트롤: 월드 투어  8.86
# 24 NaN          시티 오브 갓  8.84
# 25 NaN           미녀와 야수  8.78
# 26 NaN    부에나 비스타 소셜 클럽  8.78
# 27 NaN              소공녀  8.77
# 28 NaN               벌새  8.76
# 29 NaN              현기증  8.73
# ...
